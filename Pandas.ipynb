# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathiskar/ML_Study/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library
#
#   useful for data processing and Analysis
#
#
#
#
#
#
#
#
#
# Pandas Data Frame
#
#
#   Pandas DataFrame is two dimensional tablar data structure with labeled axes (rows and columns)

# %%
#import the pandas library
import pandas as pd
#import the NumPy library
import numpy as np

# %% [markdown]
# Creating a Pandas Data Frame

# %%
#import the Boston house price data
from sklearn.datasets import load_diabetes
dataset = load_diabetes()

# %%
type(dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(dataset)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
#pandas DataFrame
data_df = pd.DataFrame(dataset.data, columns = dataset.feature_names)

# %%
data_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
data_df.shape
# Out:
# (442, 10)

# %% [markdown]
# Importing the data from a csv file to a pandas DataFrame

# %%
#csv file to pandas data frame

# %%
diabetes_df = pd.read_csv("/content/diabetes.csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from the excel file to a Pandas Data Frame
#
# pd.read_excel('file path')

# %% [markdown]
# Exporting a DataFrame to a CSV file

# %%
data_df.to_csv('data.csv')

# %% [markdown]
# Exporting the pandas DataFrame to an excel File:
#
# df.to_excel('filename')

# %%
#creating a DataFrame with random values
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.657522  0.460905  0.042419  0.663953  0.880937  0.868050  0.769859
# 1  0.364537  0.445211  0.558075  0.209095  0.257426  0.599130  0.802818
# 2  0.960358  0.191798  0.412723  0.581599  0.348106  0.604852  0.909691
# 3  0.637809  0.190433  0.965425  0.183574  0.777403  0.061077  0.640652
# 4  0.705619  0.658237  0.215198  0.676912  0.968429  0.180245  0.895665
#
#           7         8         9
# 0  0.307166  0.725496  0.834635
# 1  0.608258  0.884792  0.973288
# 2  0.283503  0.222563  0.150991
# 3  0.103724  0.511399  0.584382
# 4  0.115831  0.834768  0.759101

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a DataFrame

# %%
#finding the number of rows and columns
data_df.shape
# Out:
# (442, 10)

# %%
# first 5 rows in a data frame
data_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
#last 5 rows
data_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
#information about the data frame
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
#finding the number of missing values
data_df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
# diabetses dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# diabetes dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the values based in the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_df.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 52     8
# 44     8
# 50     8
# 51     8
# 58     7
# 54     6
# 47     6
# 53     5
# 60     5
# 49     5
# 57     5
# 48     5
# 66     4
# 62     4
# 63     4
# 55     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %%
# group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
# count or number of values
data_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
# mean value column wise
data_df.mean()
# Out:
# age   -1.444295e-18
# sex    2.543215e-18
# bmi   -2.255925e-16
# bp    -4.854086e-17
# s1    -1.428596e-17
# s2     3.898811e-17
# s3    -6.028360e-18
# s4    -1.788100e-17
# s5     9.243486e-17
# s6     1.351770e-17
# dtype: float64

# %%
# standard deviation
data_df.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
# minium value
data_df.min()
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112399
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
# max value
data_df.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
# all the statistical measures of the dataFrame
data_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %% [markdown]
# Manipulating the dataFrame

# %%
# adding a column to a dataFrame
data_df['Price'] = dataset.target

# %%
data_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Price
# 0 -0.002592  0.019907 -0.017646  151.0
# 1 -0.039493 -0.068332 -0.092204   75.0
# 2 -0.002592  0.002861 -0.025930  141.0
# 3  0.034309  0.022688 -0.009362  206.0
# 4 -0.002592 -0.031988 -0.046641  135.0

# %%
# removing a row
data_df.drop(index=0, axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  Price
# ...

# %%
# removing a column
data_df.drop(columns = 'bp', axis=1)
# Out:
#           age       sex       bmi        s1        s2        s3        s4  \
# 0    0.038076  0.050680  0.061696 -0.044223 -0.034821 -0.043401 -0.002592
# 1   -0.001882 -0.044642 -0.051474 -0.008449 -0.019163  0.074412 -0.039493
# 2    0.085299  0.050680  0.044451 -0.045599 -0.034194 -0.032356 -0.002592
# 3   -0.089063 -0.044642 -0.011595  0.012191  0.024991 -0.036038  0.034309
# 4    0.005383 -0.044642 -0.036385  0.003935  0.015596  0.008142 -0.002592
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662 -0.005697 -0.002566 -0.028674 -0.002592
# 438 -0.005515  0.050680 -0.015906  0.049341  0.079165 -0.028674  0.034309
# 439  0.041708  0.050680 -0.015906 -0.037344 -0.013840 -0.024993 -0.011080
# 440 -0.045472 -0.044642  0.039062  0.016318  0.015283 -0.028674  0.026560
# 441 -0.045472 -0.044642 -0.073030  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6  Price
# 0    0.019907 -0.017646  151.0
# ...

# %%
# locating a row using the index value
data_df.iloc[2]
# Out:
# age        0.085299
# sex        0.050680
# bmi        0.044451
# bp        -0.005670
# s1        -0.045599
# s2        -0.034194
# s3        -0.032356
# s4        -0.002592
# s5         0.002861
# s6        -0.025930
# Price    141.000000
# Name: 2, dtype: float64

# %%
# locating a particular column
print(data_df.iloc[:,0]) #first column
print(data_df.iloc[:,1]) #2nd column
print(data_df.iloc[:,2]) #3rd column
print(data_df.iloc[:,-1]) #last column
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64
# 0      0.050680
# 1     -0.044642
# 2      0.050680
# 3     -0.044642
# 4     -0.044642
#          ...
# 437    0.050680
# 438    0.050680
# 439    0.050680
# 440   -0.044642
# 441   -0.044642
# Name: sex, Length: 442, dtype: float64
# 0      0.061696
# 1     -0.051474
# 2      0.044451
# 3     -0.011595
# 4     -0.036385
#          ...
# 437    0.019662
# 438   -0.015906
# 439   -0.015906
# 440    0.039062
# 441   -0.073030
# Name: bmi, Length: 442, dtype: float64
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: Price, Length: 442, dtype: float64

# %% [markdown]
# Correlation
#
#   1. positive corelation
#   2. Negative correlation

# %%
data_df.corr()
# Out:
#             age       sex       bmi        bp        s1        s2        s3  \
# age    1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex    0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi    0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp     0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1     0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2     0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3    -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4     0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5     0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6     0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Price  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#              s4        s5        s6     Price
# ...
